# %%
print("Hello world ")
# Out:
# Hello world

# %%
# strings ,number basics ,comments error messages 
# Expressions ...pyhon shell,mixed data types ,maths modules ,floating points errors and code formating 
# Objects --strings ,lists ,tuples ,Dictionaries 
# Decisions  ..if - else statements ,Bolean expressions ,operators presidence ,Neted decisions 
# Loops ..while loop ,for loop ,nested loops ,break and continue ..loop else
# Functions ..controll flow ,variable scope ,parameters and return Values 
# Classes  OOP Basics  clases and instances ,oerloading operators and instance method s
# Inheritance ..Inheritance basics ,attrinutes and method 
# Files ,,readin from files ,writting from files and Handling exceptions 
# Data Scienec .Intro to Datascience ...Numpy and pandas ,Data visualizations 
 
 
# Programs consits of  statements to be run after the other 
# A statement describe some action to be carried out e.G
# print()..used for output all the message to the user 
# The statement Count=0 ..assigning a value to the variable count 
# syntax is concised and straght forward ;and thats why its popular .....!!!

# JAVA HELLO WORD 
# Public Class Helloword{
#   public static void main(string ,args[] ){
#               system.out.println ("Hello worrld");
#       }

#    }
# PYTHON 
# print('Hello world ')   
  
# Java uses 5 lines to display the hello world message 
# However in constrast python uses one line to out put the same message

#  1:in general  python programs are -- than java 
#  A shorter
#  2:In example above what syntax required by java is not required by python 
#  semi-colon 
#  3 Write a python program ask for fav song and display it to the user
 
 
#  n=input("Enter ur fav song ")

   
#  The print functions display output to the user 
# #  the sep and end can be used to customized theoutput 

#multiple valuse separted by comma can be printed in the same statement
#by default each value is separated by space in the output  the sep parameter can be used to change this behaviour
#by defaut the prints() adds a new line after each output the 
#A new line xter tells the display to move to the next line after printing the output
#The end option can be used to continue printing on the same line 
#print("Hello","world","!!!",sep="***",end=" ")
#write a python program to display the following words on diff lines 
#Today is a moday

# %%
n=int(input("Enter the song u like "))
'{}'.format(n)
# Out:
# '5'

# %%
print("Today\nis\nMonday")
# Out:
# Today
# is
# Monday

# %%
print("Today", "is", "monday", sep="\n") #using the sep operator
# Out:
# today
# is
# monday

# %%
# using the end operator
#u have been given the following statements
#today is wednesday
#Arsenal will win against manchester united
#using end operator display the above statements on the same line

print("Today is wednesday ", end="")       
print("Arsenal will win against manchester united")
# Out:
# Today is wednesday Arsenal will win against manchester united

# %%
# inputs 
# computer program often receive input from the user
#its what the user enter into a programs 
#An input statemente var=input("prompt string") has 3 parts
#the first part is var ...value stored in memory  ..this can be replace with anyy name the dev chooses
#the second part is input() ...this is a built in function that reads a line of text from the user
# a function is name as a re usable block of code that performs a  task when called
#The input is stored in the computer memory and can be accesssed laer using the variable name
#the third part is the prompt string ...this is a short  message displayed to the user before the input is read or waiting the prpram to accept input
#the prompt can be ommited in the above example or replace with any message 
#some one name d sofia enters their name when prompted with the following statements 
#print(" please Enter your name:")
#name=input()
print(" please Enter your name:")
name=input()
print("Please enter ur name ",name)
# Out:
#  please Enter your name:
# Please enter ur name sofia  juma

# %%
print("Hello ",name)
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# print("The current time is :",curenttime)
import math
# the formula for quadratics 
a=float(input("Enter the inputs of a :"))
b=float(input("Enter the inputs of b:"))
c=float(input("Enter the input of c:"))
deno=2*a
import math
sqrts=((b*b-(4*a*c)))
if sqrts <0:
    print("There is invalid entry try another number ")
else:
    positive=(-b+sqrts)/deno
    another=(b+sqrts)/deno
    print("The first value is :",positive)
    print("The second value is :",another)
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
