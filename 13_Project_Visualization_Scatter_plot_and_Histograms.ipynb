# %% [markdown]
# # Project - Horsepower vs Torque and Roll Dice
# ### Goal
# - Learn how to make scatter plot and histograms

# %% [markdown]
# ### Horsepower vs Torque
# - Import matplotlib.pyplot as plt and use %matplotlib inline.
# - Import csv
# - Read the files/cars.csv wil into a list of dictionaries.
# - Use list comprehension to get
#     - Horsepwer
#     - Torque
#     - Bonus: Fuel City mpg
# - Make a scatter plot
#     - Options: Use alpha=.25 and c= with the list of Fuel City mpg

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
# Out:
# /usr/lib/python3/dist-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import urllib.request
import csv

# %%
import csv

remote_file = "/home/activator/Desktop/Learn-Python-With-Juma/files/cars.csv"

# Open the local file
with open(remote_file, mode='r') as f:
    csv_reader = csv.DictReader(f)
    cars = list(csv_reader)

print(cars)
# Out:
# [{'Height': '140', 'Length': '143', 'Width': '202', 'Engine Driveline': 'All-wheel drive', 'Engine Type': 'Audi 3.2L 6 cylinder 250hp 236ft-lbs', 'Engine Hybrid': 'True', 'Number of Forward Gears': '6', 'Engine Transmission': '6 Speed Automatic Select Shift', 'Fuel City mpg': '18', 'Fuel Type': 'Gasoline', 'Fuel Highway mpg': '25', 'Classification': 'Automatic transmission', 'ID': '2009 Audi A3 3.2', 'Make': 'Audi', 'Model Year': '2009 Audi A3', 'Year': '2009', 'Horsepower': '250', 'Torque': '236'}, {'Height': '140', 'Length': '143', 'Width': '202', 'Engine Driveline': 'Front-wheel drive', 'Engine Type': 'Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo', 'Engine Hybrid': 'True', 'Number of Forward Gears': '6', 'Engine Transmission': '6 Speed Automatic Select Shift', 'Fuel City mpg': '22', 'Fuel Type': 'Gasoline', 'Fuel Highway mpg': '28', 'Classification': 'Automatic transmission', 'ID': '2009 Audi A3 2.0 T AT', 'Make': 'Audi', 'Model Year': '2009 Audi A3', 'Year': '2009', 'Horsepower': '200', 'Torque': '207'}, {'Height': '140', 'Length': '143', 'Width': '202', 'Engine Driveline': 'Front-wheel drive', 'Engine Type': 'Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo', 'Engine Hybrid': 'True', 'Number of Forward Gears': '6', 'Engine Transmission': '6 Speed Manual', 'Fuel City mpg': '21', 'Fuel Type': 'Gasoline', 'Fuel Highway mpg': '30', 'Classification': 'Manual transmission', 'ID': '2009 Audi A3 2.0 T', 'Make': 'Audi', 'Model Year': '2009 Audi A3', 'Year': '2009', 'Horsepower': '200', 'Torque': '207'}, {'Height': '140', 'Length': '143', 'Width': '202', 'Engine Driveline': 'All-wheel drive', 'Engine Type': 'Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo', 'Engine Hybrid': 'True', 'Number of Forward Gears': '6', 'Engine Transmission': '6 Speed Automatic Select Shift', 'Fuel City mpg': '21', 'Fuel Type': 'Gasoline', 'Fuel Highway mpg': '28', 'Classification': 'Automatic transmission', 'ID': '2009 Audi A3 2.0 T Quattro', 'Make': 'Audi', 'Model Year': '2009 Audi A3', 'Year': '2009', 'Horsepower': '200', 'Torque': '207'}, {'Height': '140', 'Length': '143', 'Width': '202', 'Engine Driveline': 'All-wheel drive', 'Engine Type': 'Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo', 'Engine Hybrid': 'True', 'Number of Forward Gears': '6', 'Engine Transmission': '6 Speed Automatic Select Shift', 'Fuel City mpg': '21', 'Fuel Type': 'Gasoline', 'Fuel Highway mpg': '28', 'Classification': 'Automatic transmission', 'ID': '2009 Audi A3 2.0 T Quattro', 'Make': 'Audi', 'Model Year': '2009 Audi A3', 'Year': '2009', 'Horsepower': '200', 'Torque': '207'}, {'Height': '91', 'Length': '17', 'Width': '62', 'Engine Driveline': 'All-wheel drive', 'Engine Type': 'Audi 3.2L 6 cylinder 265hp 243 ft-lbs', 'Engine Hybrid': 'True', 'Number of Forward Gears': '6', 'Engine Transmission': '6 Speed Manual', 'Fuel City mpg': '16', 'Fuel Type': 'Gasoline', 'Fuel Highway mpg': '27', 'Classification': 'Manual transmission', 'ID': '2009 Audi A5 3.2', 'Make': 'Audi', 'Model Year': '2009 Audi A5', 'Year': '2009', 'Horsepower': '265', 'Torque': '243'}, {'Height': '91', 'Length': '17', 'Width': '62', 'Engine Driveline': 'All-wheel drive', 'Engine Type': 'Audi 3.2L 6 cylinder 265hp 243 ft-lbs', 'Engine Hybrid': 'True', 'Number of Forward Gears': '6', 'Engine Transmission': '6 Speed Automatic Select Shift', 'Fuel City mpg': '17', 'Fuel Type': 'Gasoline', 'Fuel Highway mpg': '26', 'Classification': 'Automatic transmission', 'ID': '2009 Audi A5 3.2 AT', 'Make': 'Audi', 'Model Year': '2009 Audi A5', 'Year': '2009', 'Horsepower': '265', 'Torque': '243'}, {'Height': '201', 'Length': '221', 'Width': '191', 'Engine Driveline': 'All-wheel drive', 'Engine Type': 'Audi 4.2L 8 cylinder 350 hp 325 ft-lbs', 'Engine Hybrid': 'True', 'Number of Forward Gears': '6', 'Engine Transmission': '6 Speed Automatic Select Shift', 'Fuel City mpg': '13', 'Fuel Type': 'Gasoline', 'Fuel Highway mpg': '18', 'Classification': 'Automatic transmission', 'ID': '2009 Audi Q7 4.2', 'Make': 'Audi', 'Model Year': '2009 Audi Q ...

# %%
cars[0]
# Out:
# {'Height': '140',
#  'Length': '143',
#  'Width': '202',
#  'Engine Driveline': 'All-wheel drive',
#  'Engine Type': 'Audi 3.2L 6 cylinder 250hp 236ft-lbs',
#  'Engine Hybrid': 'True',
#  'Number of Forward Gears': '6',
#  'Engine Transmission': '6 Speed Automatic Select Shift',
#  'Fuel City mpg': '18',
#  'Fuel Type': 'Gasoline',
#  'Fuel Highway mpg': '25',
#  'Classification': 'Automatic transmission',
#  'ID': '2009 Audi A3 3.2',
#  'Make': 'Audi',
#  'Model Year': '2009 Audi A3',
#  'Year': '2009',
#  'Horsepower': '250',
#  'Torque': '236'}

# %%
horsepower = [int(car['Horsepower']) for car in cars]
torque = [int(car['Torque']) for car in cars]
mpg = [int(car['Fuel City mpg']) for car in cars]

# %%
fig, ax = plt.subplots()

ax.scatter(horsepower, torque, alpha=.25, c=mpg)
ax.set_title("Horsepower vs Torque")
ax.set_xlabel("Horsepower")
ax.set_ylabel("Torque")
# Out:
# Text(0, 0.5, 'Torque')

# %% [markdown]
# ### Roll Dice
# - Import random
# - Create a functin role_dice(), which simulates a roll of 2 dice.
# - Use list comprehension to create a list of 500 calls to role_dice().
# - Create a histogram with 11 bins of the list.

# %%
import random

# %%
def roll_dice():
  return random.randint(1, 6) + random.randint(1, 6)

# %%
roll_dice()
# Out:
# 2

# %%
dice_data = [roll_dice() for it in range(500)]

# %%
len(dice_data)
# Out:
# 500

# %%
min(dice_data)
# Out:
# 2

# %%
max(dice_data)
# Out:
# 12

# %%
fig, ax = plt.subplots()

ax.hist(dice_data, bins = 11)
# Out:
# (array([11., 28., 42., 50., 72., 85., 59., 58., 44., 39., 12.]),
#  array([ 2.        ,  2.90909091,  3.81818182,  4.72727273,  5.63636364,
#          6.54545455,  7.45454545,  8.36363636,  9.27272727, 10.18181818,
#         11.09090909, 12.        ]),
#  <BarContainer object of 11 artists>)
